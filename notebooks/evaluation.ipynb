# %% [markdown]
# # 1. Load Datasets

# %% [markdown]
# ## 1.1 Load Model Predictions

# %%
from pathlib import Path
import re
import pandas as pd

# Show all columns, but truncate cell content to keep rows readable
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
pd.set_option("display.max_colwidth", 80)  #

def _find_results_root(start: Path | None = None) -> Path:
    p = (start or Path.cwd()).resolve()
    for _ in range(6):
        candidate = p / "evaluation" / "results"
        if candidate.exists() and candidate.is_dir():
            return candidate
        p = p.parent
    raise FileNotFoundError("Could not locate 'evaluation/results' directory from current path upwards.")

def load_batch_csvs(app_names: list[str], results_root: Path | None = None) -> list[pd.DataFrame]:
    root = results_root or _find_results_root()
    batch_dfs: list[pd.DataFrame] = []
    for app in app_names:
        app_dir = root / app
        if not app_dir.exists():
            print(f"[skip] App dir not found: {app_dir}")
            continue
        batch_dirs = sorted(
            [d for d in app_dir.glob("batch_*") if d.is_dir()],
            key=lambda d: int(re.match(r"batch_(\d+)$", d.name).group(1)) if re.match(r"batch_(\d+)$", d.name) else 0,
        )
        for bdir in batch_dirs:
            m = re.match(r"batch_(\d+)$", bdir.name)
            if not m:
                print(f"[skip] Unrecognized batch dir: {bdir}")
                continue
            batch_id = int(m.group(1))
            csv_path = bdir / "csv" / f"batch_{batch_id}.csv"
            if not csv_path.exists():
                print(f"[skip] CSV missing: {csv_path}")
                continue
            df = pd.read_csv(csv_path)
            df["app"] = app
            df["batch_id"] = batch_id
            batch_dfs.append(df)
            print(f"[ok] Loaded {csv_path} with {len(df)} rows")
    return batch_dfs

# %%
apps = ["01", "02", "03", "04", "05"]
batch_frames = load_batch_csvs(apps)
combined = pd.concat(batch_frames, ignore_index=True) if batch_frames else pd.DataFrame()
print(len(combined))
combined
# Out:
# [ok] Loaded C:\Users\krkol\Documents\workspaces\tuc_workspace\GUI-Spector\evaluation\results\01\batch_1\csv\batch_1.csv with 12 rows
# [ok] Loaded C:\Users\krkol\Documents\workspaces\tuc_workspace\GUI-Spector\evaluation\results\01\batch_2\csv\batch_2.csv with 12 rows
# [ok] Loaded C:\Users\krkol\Documents\workspaces\tuc_workspace\GUI-Spector\evaluation\results\01\batch_3\csv\batch_3.csv with 6 rows
# [ok] Loaded C:\Users\krkol\Documents\workspaces\tuc_workspace\GUI-Spector\evaluation\results\02\batch_1\csv\batch_1.csv with 11 rows
# [ok] Loaded C:\Users\krkol\Documents\workspaces\tuc_workspace\GUI-Spector\evaluation\results\02\batch_2\csv\batch_2.csv with 12 rows
# [ok] Loaded C:\Users\krkol\Documents\workspaces\tuc_workspace\GUI-Spector\evaluation\results\02\batch_3\csv\batch_3.csv with 6 rows
# [ok] Loaded C:\Users\krkol\Documents\workspaces\tuc_workspace\GUI-Spector\evaluation\results\03\batch_1\csv\batch_1.csv with 12 rows
# [ok] Loaded C:\Users\krkol\Documents\workspaces\tuc_workspace\GUI-Spector\evaluation\results\03\batch_2\csv\batch_2.csv with 12 rows
# [ok] Loaded C:\Users\krkol\Documents\workspaces\tuc_workspace\GUI-Spector\evaluation\results\03\batch_3\csv\batch_3.csv with 6 rows
# [ok] Loaded C:\Users\krkol\Documents\workspaces\tuc_workspace\GUI-Spector\evaluation\results\04\batch_1\csv\batch_1.csv with 12 rows
# [ok] Loaded C:\Users\krkol\Documents\workspaces\tuc_workspace\GUI-Spector\evaluation\results\04\batch_2\csv\batch_2.csv with 12 rows
# [ok] Loaded C:\Users\krkol\Documents\workspaces\tuc_workspace\GUI-Spector\evaluation\results\04\batch_3\csv\batch_3.csv with 6 rows
# [ok] Loaded C:\Users\krkol\Documents\workspaces\tuc_workspace\GUI-Spector\evaluation\results\05\batch_1\csv\batch_1.csv with 11 rows
# [ok] Loaded C:\Users\krkol\Documents\workspaces\tuc_workspace\GUI-Spector\evaluation\results\05\batch_2\csv\batch_2.csv with 12 rows
# [ok] Loaded C:\Users\krkol\Documents\workspaces\tuc_workspace\GUI-Spector\evaluation\results\05\batch_3\csv\batch_3.csv with 6 rows
# 148
#                            requirement_id rand_id  \
# 0    2aa7e914-3995-4185-a6e0-87b60d01584f    CQ26
# 1    de7e84a1-a821-43b6-a476-349d4a2907da    DO84
# 2    f026cdd0-a01b-4dab-b13f-50847d7216be    DQ56
# 3    e708410e-711c-4183-ae46-bce1889baff9    DQ80
# 4    ffd0117f-5cea-4bd7-90d5-160f4d2b8e46    LH51
# 5    6e04c7f6-523a-47e8-b3e4-d0d2019fcbf5    MH44
# 6    4dc4be42-614b-494f-b2d2-71d2b01dfc3e    MI48
# 7    d38cb45c-63f9-49d1-930a-3cb8e462411c    MT45
# 137  ed5c4579-2291-448c-b5fc-d510ad41a689    ML84
# 138  04fa25d3-427e-4d77-a882-2cbe8bc984ad    UW71
# 139  7f8af3b2-3ceb-4d0f-b8cf-50f0967323ca    VT73
# 140  51dd408a-3bf1-40ce-936c-ff91f1b54622    WO65
# 141  349d06f9-ef74-4d1f-8bc2-7c9faae4b8e0    WX62
# 142  27c92205-a9cc-473f-8d00-ed0a60bb8089    IL18
# 143  a319b154-74d6-4b44-88a1-790601af0e6d    IP20
# 144  4f76cddc-db9e-432e-a18b-7b0aa8df8b2e    NR91
# 145  f57f00d8-1aa4-4b45-9c7a-e295832fa6be    OE29
# 146  e6925472-a436-4358-9945-dd11ad6b1fd8    XC06
# 147  0cb1b5e2-49d2-4e4b-b434-ee5f598896e2    YF72
#
#                                                                                title  \
# 0    Users shall be able to filter parking options by vehicle type such as Standa...
# 1             App shall maintain a reservation history list stored in local storage.
# 2    App shall allow users to scan their license plate via device camera to auto-...
# 3      App shall display a mock occupancy trend chart for the selected parking spot.
# 4         Users shall be able to add and remove parking spots from a favorites list.
# 5    App shall produce a downloadable parking receipt file for each completed res...
# 6    App shall display zone-specific parking regulations within the spot detail p...
# 7             Users shall manage a primary vehicle profile for reservation defaults.
# 8    User shall be able to cancel an active reservation via the reservation manag...
# 9     Parking list shall support sorting by price and by estimated walking distance.
# 10   Search field shall allow users to locate parking options by entering an addr...
# 11   Checkout flow shall allow entry of promo codes to apply discounts to parking...
# 12   App shall automatically refresh parking availability statuses every 60 secon...
# 13     App shall support scheduling reservations for any future date within 30 days.
# 14   App shall verify resident parking permits by connecting to the municipal per...
# 15   App shall provide a price range slider to narrow parking options by hourly r...
# 16   App shall offer a language toggle between English and Spanish across all use...
# 17   Selecting a parking entry shall open a detail panel with comprehensive spot ...
# 18   Each parking entry shall display its current availability status using color...
# 19   App shall allow the user to create a parking reservation stored in browser l...
# 20   App shall send browser push notifications reminding users 15 minutes before ...
# 21   A toggle control shall allow users to switch between combined map-plus-list ...
# 22   App shall provide step-by-step walking directions preview from current locat...
# 23   App shall provide an offline mode showing last-synced parking data when netw...
# 24   App shall generate a shareable deep-link that reopens the app with the reser...
# 25   Dragging the map shall refresh the parking list based on the map's current v...
# 26   App shall display a live countdown timer for the upcoming reservation start ...
# 27               App shall simulate payment checkout to confirm reservation charges.
# 28   App shall present an onboarding tutorial overlay highlighting key controls o...
# 29   App shall load with a combined map and list of nearby parking options source...
# 30   Display a dashboard summary showing total income, total expenses, and balanc...
# 31        Support inline editing of existing transactions to adjust details quickly.
# 32                                    Provide a print-friendly monthly summary view.
# 33   Support recurring transactions that auto-populate future months based on fre...
# 34   Persist all transactions and settings using browser localStorage automatically.
# 35                      Allow users to reset all stored data from a settings action.
# 36        Enable natural language input for adding transactions via typed sentences.
# 37                       Provide quick-add expense templates for frequent purchases.
# 38   Allow users to delete transactions with confirmation to prevent accidental l...
# 39      Display a spending by category bar chart that reacts to the active data set.
# 40   Allow users to duplicate an existing transaction for faster entry of similar...
# 41   Provide month navigation controls to view previous and next month budgets wi...
# 42   Allow the user to add income transactions that contribute to monthly income ...
# 43   Allow the user to add a new expense transaction through a modal form capturi...
# 44                   Display the average daily expense value for the selected month.
# 45               Allow users to customize category colors used in charts and badges.
# 46                Generate insight summaries highlighting notable spending patterns.
# 47          Offer a view switcher between list-focused and insights-focused layouts.
# 48   Allow drag-and-drop reordering of categories to influence list and chart order.
# 49                          Allow users to set a monthly budget threshold per month.
# 50          Provide keyword search across transaction memos with real-time feedback.
# 51          Provide automatic currency conversion for foreign currency transactions.
# 52            Display a warning when spending exceeds the configured monthly budget.
# 53       Allow users to create and switch between multiple personal budget profiles.
# 54   Maintain a transaction list sorted by date in descending order with clear fo...
# 55   Allow the user to create custom expense categories that become available thr...
# 56   Provide a category filter allowing multi-selection to refine the transaction...
# 57   Support tagging transactions with arbitrary labels and filtering by those tags.
# 58   Provide a dynamic daily spending allowance suggestion based on remaining bud...
# 59   The system shall provide quick-add buttons for at least eight common ingredi...
# 60    The system shall generate a grocery pickup list organized by aisle categories.
# 61   The system shall allow users to schedule generated recipes across a seven-da...
# 62                 The system shall permit users to attach photos to custom recipes.
# 63   The system shall allow users to edit ingredient names and quantity notes inl...
# 64   The system shall display summary counters of tracked ingredients by availabi...
# 65   The system shall build a consolidated shopping list from missing ingredients...
# 66   The system shall provide a 'Surprise Me' feature that opens a random recipe ...
# 67   The system shall generate a list of recipe suggestions prioritized by alignm...
# 68   The system shall support drag-and-drop reordering of ingredients into a cust...
# 69   The system shall allow users to export the current inventory to a downloadab...
# 70             The system shall support keyword search across recipe names and tags.
# 71           The system shall allow users to filter recipes by meal type categories.
# 72   The system shall allow users to toggle each ingredient between 'In Fridge' a...
# 73              The system shall persist the fridge inventory using browser storage.
# 74   The system shall enable users to mark ingredients with a 'Use Soon' flag for...
# 75   The system shall let users adjust recipe servings and automatically scale in...
# 76   The system shall allow users to add a new ingredient with optional quantity ...
# 77   The system shall let users sort the ingredient list by recency or alphabetic...
# 78              The system shall allow users to import ingredients from a JSON file.
# 79    The system shall allow creation and application of custom dietary filter tags.
# 80   The system shall deliver a guided cooking mode with interactive timers for t...
# 81   The system shall allow users to favorite recipes and review them in a dedica...
# 82   The system shall enable users to delete any existing ingredient from the inv...
# 83   The system shall offer substitution suggestions for missing ingredients from...
# 84   The system shall track ingredient expiration dates and signal upcoming expir...
# 85          The system shall allow users to create, save, and manage custom recipes.
# 86         The system shall display missing ingredients for every recipe suggestion.
# 87   The system shall present a recipe detail view with full instructions when a ...
# 88               The system shall enable users to rate recipes on a five-star scale.
# 89   The app shall deliver multi-stage quest lines that unlock sequential challen...
# 90         The app shall track daily check-ins to maintain a workout streak counter.
# 91   The app shall display a list of daily fitness challenges categorized by focu...
# 92   The app shall calculate estimated calories burned based on user input for ea...
# 93   The app shall show a progress bar that reflects completion percentage of the...
# 94   The app shall present a first-time onboarding flow that captures the user's ...
# 95   The app shall provide a quick challenge generator that suggests a randomized...
# 96   The app shall allow users to schedule in-app reminders for upcoming challenges.
# 97   The app shall provide a challenge detail view with objectives, time estimate...
# 98   The app shall allow users to create custom challenges with chosen activities...
# 99   The app shall enable users to invite friends by generating shareable challen...
# 100  The app shall present a weekly summary modal highlighting key metrics every ...
# 101  The app shall support avatar customization with selectable outfits, accessor...
# 102  The app shall include a feedback form for users to submit suggestions or iss...
# 103              The app shall support scheduling rest days that pause streak decay.
# 104  The app shall render a calendar view marking daily activity, rest days, and ...
# 105  The app shall offer voice coaching prompts during active challenges using te...
# 106          The app shall maintain a chronological history of completed challenges.
# 107   The app shall award achievement badges when users reach predefined milestones.
# 108  The app shall implement a leveling system that increases the user's level ba...
# 109  The app shall allow the user to start a challenge and switch the interface t...
# 110       The app shall export the user’s progress data to a downloadable JSON file.
# 111  The app shall provide an interactive tutorial guiding new users through prim...
# 112  The app shall display a community leaderboard highlighting the top ten playe...
# 113  The app shall provide a reward store where users redeem points for cosmetic ...
# 114  The app shall allow the creation of group challenges where users collaborate...
# 115   The app shall generate a shareable text summary of the user’s weekly progress.
# 116  The app shall let users log repetitions or sets completed within an active c...
# 117  The app shall allow users to capture and manage progress photos for challeng...
# 118  The app shall provide a sound effects toggle to control audio feedback on in...
# 119  The app shall allow customers to cancel a booking from the 'My Bookings' lis...
# 120  The app shall allow users to edit any aspect of an existing booking before i...
# 121             The app shall allow customers to choose preferred cleaning duration.
# 122  The app shall present a step indicator showing progress through the booking ...
# 123            The app shall support scheduling recurring bookings in a single flow.
# 124    The app shall collect customer contact information before booking submission.
# 125  The app shall store confirmed bookings in client-side session for later view...
# 126         The app shall let customers choose optional service add-ons via toggles.
# 127  The app shall support filtering bookings by status (Pending, Completed, Canc...
# 128          The app shall provide an expandable booking detail view for each entry.
# 129  The app shall generate a confirmation view with a unique booking reference a...
# 130  The app shall generate a dynamic pricing estimate based on the booking selec...
# 131  The app shall include a contact form for service inquiries accessible from n...
# 132     The app shall allow users to duplicate an existing booking into a new draft.
# 133  The app shall capture a digital signature from the cleaner or customer upon ...
# 134  The app shall provide a date and time slot picker for scheduling the cleanin...
# 135  The app shall present real-time cleaner location tracking on the booking con...
# 136  The app shall present a landing view summarizing cleaning services with a pr...
# 137  The app shall allow customers to assign a preferred cleaner profile to their...
# 138  The app shall support full localization with a language toggle for English a...
# 139  The app shall display a status timeline for each booking covering Requested,...
# 140  The app shall let users export a booking to their personal calendar via down...
# 141  The app shall provide a drag-and-drop interface to reschedule bookings on a ...
# 142  The app shall present a booking review screen summarizing all selections bef...
# 143  The app shall provide sharing options to send booking confirmations via emai...
# 144                    The app shall capture service address and entry instructions.
# 145                   The app shall allow users to mark a completed booking as done.
# 146  The app shall allow customers to choose a cleaning service category from int...
# 147  The app shall support applying multiple promo codes per booking with cumulat...
#
#             status                        started_at  \
# 0              met  2025-09-28T14:43:22.930788+00:00
# 1              met  2025-09-28T14:50:44.569639+00:00
# 2            unmet  2025-09-28T14:57:12.659429+00:00
# 3              met  2025-09-28T14:58:48.259754+00:00
# 21                   http://192.168.178.40:8010/            4
# 22                   http://192.168.178.40:8010/           16
# 23                   http://192.168.178.40:8010/           37
# 24           http://192.168.178.40:8010/?spot=P4           39
# 25                   http://192.168.178.40:8010/           18
# 26                   http://192.168.178.40:8010/           62
# 27                   http://192.168.178.40:8010/           22
# 28                   http://192.168.178.40:8010/           12
# 29                   http://192.168.178.40:8010/            7
# 30                   http://192.168.178.40:8010/           31
# 31                   http://192.168.178.40:8010/           37
# 32                   http://192.168.178.40:8010/            9
# 33                   http://192.168.178.40:8010/           14
# 34                    http://192.168.178.40:8010           50
# 35                   http://192.168.178.40:8010/            8
# 36                   http://192.168.178.40:8010/           15
# 37                   http://192.168.178.40:8010/           15
# 38                   http://192.168.178.40:8010/           10
# 39                   http://192.168.178.40:8010/           28
# 40                   http://192.168.178.40:8010/           16
# 41                   http://192.168.178.40:8010/           13
# 42                   http://192.168.178.40:8010/            9
# 43                   http://192.168.178.40:8010/            5
# 44                   http://192.168.178.40:8010/           25
# 45                   http://192.168.178.40:8010/           16
# 46                   http://192.168.178.40:8010/           34
# 47                   http://192.168.178.40:8010/           25
# 48                   http://192.168.178.40:8010/           15
# 49                   http://192.168.178.40:8010/           16
# 50                   http://192.168.178.40:8010/           12
# 51                   http://192.168.178.40:8010/           16
# 52                   http://192.168.178.40:8010/           18
# 53                   http://192.168.178.40:8010/           13
# 54                   http://192.168.178.40:8010/           79
# 55                   http://192.168.178.40:8010/           16
# 56                   http://192.168.178.40:8010/           21
# 57                   http://192.168.178.40:8010/           29
# 58                   http://192.168.178.40:8010/           18
# 59                   http://192.168.178.40:8010/           15
# 60                   http://192.168.178.40:8010/           22
# 61                   http://192.168.178.40:8010/           18
# 62                   http://192.168.178.40:8010/           27
# 63                   http://192.168.178.40:8010/           97
# 64                   http://192.168.178.40:8010/           23
# 65                   http://192.168.178.40:8010/           34
# 66                   http://192.168.178.40:8010/            7
# 67                   http://192.168.178.40:8010/           11
# 68                   http://192.168.178.40:8010/           22
# ...
# 21   Clicking the toggle again restores the combined map and list layout without ...
# 22   Directions can be dismissed to return to the detail panel without losing con...
# 23     App queues user actions made offline and syncs them once connection restores.
# 24   Opening the generated URL preloads the app state to focus on the reserved spot.
# 25                     List update occurs without requiring a manual refresh button.
# 26                           Timer stops at zero and changes status to 'Active Now'.
# 27   Invalid or incomplete payment fields display inline validation messages and ...
# 28   Completing or skipping the tutorial sets a flag in local storage to prevent ...
# 29   No user interaction is required to see initial parking options in both map a...
# 30   Displayed balance equals total income minus total expenses for the selected ...
# 31     Cancelling an edit restores the original transaction content without changes.
# 32              Button triggers browser print dialog with pre-filled document title.
# 33              Users can pause or cancel a recurring series from a management view.
# 34        Clearing browser storage removes data and the app presents an empty state.
# 35   Confirmed reset clears localStorage and reloads the app to an initial empty ...
# 36                Parsed transaction preview appears for confirmation before saving.
# 37      Users can customize the quick-add presets directly within the app interface.
# 38   Confirmed deletions remove the entry from list, chart, and storage immediately.
# 39                       Chart respects active category filters and month selection.
# 40         User can change duplicated transaction type if desired before committing.
# 41                   Selected month state persists across visits using localStorage.
# 42   Income entries are visually distinguished from expenses in the transaction l...
# 43   Saving an expense appends it to the transaction list and updates monthly tot...
# 44                        Average excludes income transactions from its computation.
# 45                                        Selected colors persist after app reloads.
# 46                   Insight text updates automatically with any transaction change.
# 47     Both views retain access to core actions such as add transaction and filters.
# 48                              New order persists across sessions via localStorage.
# 49        Budget amount is referenced by dashboards and warnings throughout the app.
# 50                     Emptying the search field restores the full transaction list.
# 51      Converted amount and original currency details display in transaction entry.
# 52   Banner reappears automatically if dismissed while overspending condition rem...
# 53                                Active profile selection persists across sessions.
# 54      Sorting automatically re-applies after every create, edit, or delete action.
# 55   Categories persist in localStorage and become available across all relevant ...
# 56         Clearing the filter returns the list and chart to showing all categories.
# 57   Filter panel includes a tags filter that lets users view only transactions w...
# 58   Allowance banner suggests specific spending adjustments when the daily limit...
# 59   Subsequent clicks on the same preset update the existing ingredient entry in...
# 60                     Users can reorder aisle sections to match their store layout.
# 61            Assigned meals persist in browser storage and can be cleared per slot.
# 62               Photo data is stored in browser storage to persist across sessions.
# 63                                 Edited values persist after the page is reloaded.
# 64                     Counters update immediately after any inventory modification.
# 65   The shopping list allows marking items as acquired while persisting the status.
# 66             The selected recipe’s detail view opens automatically upon selection.
# 67       Each recipe suggestion displays counts of matching and missing ingredients.
# 68                    The custom order persists via browser storage across sessions.
# 69                         The downloaded file name includes the current date stamp.
# 70                  Clearing the search field restores the original recipe ordering.
# 71                             Clearing the selection restores the full recipe list.
# 72   Recipe generation logic treats only ingredients marked 'In Fridge' as availa...
# 73              Refreshing or reopening the app restores the latest inventory state.
# 74                   The 'Use Soon' state is saved and restored via browser storage.
# 75            Servings selections persist for each recipe during the active session.
# 76   Adding an ingredient does not require a page reload and the new ingredient b...
# 77   The chosen sort order remains active until the user selects a different option.
# 78      The system validates file structure and notifies the user of import success.
# 79            Selecting a dietary filter restricts the recipe list to matching tags.
# 80   Completing a step automatically advances to the next instruction in guided m...
# 81   A favorites view displays only favorited recipes and updates when toggles ch...
# 82                           Removed ingredients remain absent after a page refresh.
# 83    Chosen substitutions remain applied for the recipe during the current session.
# 84            Ingredients expiring within three days show a prominent warning badge.
# 85   Custom recipes support filtering, searching, and favoriting like standard re...
# 86   Missing ingredient lists update immediately when inventory availability chan...
# 87           Closing the detail view returns to the prior list without losing state.
# 88            Recipe cards show the average rating and update after new submissions.
# 89   Quest progress is tracked separately from regular challenges and displayed i...
# 90                                  Missing a day resets the streak counter to zero.
# 91                       Selecting a challenge card opens its dedicated detail view.
# 92          The estimated calories are logged alongside the challenge history entry.
# 93                           The bar resets to zero when a new challenge is started.
# 94   The captured name and goal are stored locally and reused to personalize subs...
# 95   The user can accept the mini challenge to add it to the active challenge state.
# 96           At the reminder time, the app highlights the challenge and plays a cue.
# 97              The detail view includes a start button for launching the challenge.
# 98   Custom challenges are stored locally and can be started like predefined chal...
# 99           Entering a valid code joins the recipient to the originating challenge.
# 100         Users can dismiss the modal and view past summaries from a history link.
# 101                       Selections are saved and reflected across all app screens.
# 102       Submitted entries are viewable in a feedback log accessible from settings.
# 103  When a rest day is scheduled, missing a check-in on that date does not reset...
# 104             Users can navigate to previous months to review historical activity.
# 105         Voice prompts adjust their content based on the user’s current progress.
# 106                     History entries persist using local storage across sessions.
# 107  Earned badges are viewable in an achievements panel accessible from the dash...
# 108           A level-up animation or message is shown when a new level is achieved.
# 109  The active tracking view provides a button to complete or abandon the challe...
# 110                     The exported JSON matches the data currently stored locally.
# 111  Completion or skipping of the tutorial is stored locally to avoid replaying ...
# 112                          Users can toggle between global and friends-only views.
# 113                     Redeemed items can be equipped from within the store screen.
# 114                 Members receive notifications when the group reaches milestones.
# 115     Copying the summary provides feedback confirming the text is ready to share.
# 116    Progress updates are persisted locally so the value remains after navigation.
# 117                  Photos can be browsed chronologically and deleted individually.
# 118                   The toggle preference is saved locally and restored on reload.
# 119         Cancelled bookings are visually styled differently from active bookings.
# 120  Saving edits updates the booking summary while retaining the same reference ID.
# 121                      Selected duration is reflected in real-time price estimate.
# 122                Completed steps are indicated as finished once the user advances.
# 123                       Summary lists all future occurrences with dates and times.
# 124                    Valid entries populate the booking summary's contact section.
# 125          Booking entries include reference, service type, date/time, and status.
# 126                         Selected add-ons persist through to the booking summary.
# 127                            Resetting to 'All' shows the full booking list again.
# 128             Closing the details view returns to the list without losing context.
# 129                      Users can navigate from confirmation to 'My Bookings' view.
# 130              Final estimate is shown on the review screen prior to confirmation.
# 131                Form is accessible from main navigation without leaving the page.
# 132         New confirmation assigns a fresh booking reference even when duplicated.
# 133                            Signature is viewable from the booking details panel.
# 134                    Chosen date and time slot are summarized before confirmation.
# 135                      Location updates stop when the booking is marked completed.
# 136  Selecting 'Book Now' transitions the user to the booking wizard Step 1 witho...
# 137            Selected cleaner is stored with the booking and shown in the summary.
# 138                             User's language preference persists for the session.
# 139                  Timeline updates automatically when the booking status changes.
# 140                    Downloaded ICS file contains correct date, time, and address.
# 141        System confirms the new schedule while maintaining other booking details.
# 142               'Confirm Booking' action is available only from the review screen.
# 143  Selecting messaging copies a summarized booking link to clipboard and indica...
# 144                    Address information is displayed in the confirmation summary.
# 145                Completed bookings remain visible but are visually distinguished.
# 146     The chosen category is retained when navigating to subsequent booking steps.
# 147                 Users can remove applied codes individually before confirmation.
#
#     ac_3_status app  batch_id
# 0           met  01         1
# 1           met  01         1
# 2         unmet  01         1
# 3           met  01         1
# 4           met  01         1
# 5         unmet  01         1
# 6           met  01         1
# 7           met  01         1
# 8           met  01         1
# 9           met  01         1
# 10        unmet  01         1
# 11        unmet  01         1
# 12        unmet  01         2
# 13          met  01         2
# 14        unmet  01         2
# 15          met  01         2
# 16        unmet  01         2
# 17          met  01         2
# 18          met  01         2
# 19          met  01         2
# 20        unmet  01         2
# 21          met  01         2
# 22          met  01         2
# 23        unmet  01         2
# 24          met  01         3
# 25        unmet  01         3
# 26        unmet  01         3
# 27          met  01         3
# 28          met  01         3
# 29          met  01         3
# 30          met  02         1
# 31          met  02         1
# 32        unmet  02         1
# 33        unmet  02         1
# 34          met  02         1
# 35          met  02         1
# 36        unmet  02         1
# 37        unmet  02         1
# 38          met  02         1
# 39          met  02         1
# 40        unmet  02         1
# 41          met  02         2
# 42          met  02         2
# 43          met  02         2
# 44          met  02         2
# 45          met  02         2
# 46          met  02         2
# 47          met  02         2
# 48        unmet  02         2
# 49          met  02         2
# 50          met  02         2
# 51        unmet  02         2
# 52          met  02         2
# 53        unmet  02         3
# 54          met  02         3
# 55          met  02         3
# 56          met  02         3
# 57        unmet  02         3
# 58        unmet  02         3
# 59          met  03         1
# 60        unmet  03         1
# 61        unmet  03         1
# 62        unmet  03         1
# 63          met  03         1
# 64          met  03         1
# 65        unmet  03         1
# 66          met  03         1
# 67          met  03         1
# 68        unmet  03         1
# 69        unmet  03         1
# 70          met  03         1
# 71          met  03         2
# 72          met  03         2
# 73          met  03         2
# 74          met  03         2
# 75          met  03         2
# 76          met  03         2
# 77        unmet  03         2
# 78        unmet  03         2
# 79          met  03         2
# 80          met  03         2
# 81          met  03         2
# 82          NaN  03         2
# 83        unmet  03         3
# 84        unmet  03         3
# 85          met  03         3
# 86          met  03         3
# 87          met  03         3
# 88        unmet  03         3
# 89        unmet  04         1
# 90        unmet  04         1
# 91        unmet  04         1
# 92        unmet  04         1
# 93          met  04         1
# 94          met  04         1
# 95          met  04         1
# 96        unmet  04         1
# 97          met  04         1
# 98          met  04         1
# 99        unmet  04         1
# 100         met  04         1
# 101         met  04         2
# 102         met  04         2
# 103         met  04         2
# 104       unmet  04         2
# 105       unmet  04         2
# 106         met  04         2
# 107         met  04         2
# 108       unmet  04         2
# 109         met  04         2
# 110       unmet  04         2
# 111         met  04         2
# 112       unmet  04         2
# 113       unmet  04         3
# 114       unmet  04         3
# 115       unmet  04         3
# 116         met  04         3
# 117       unmet  04         3
# 118         met  04         3
# 119         met  05         1
# 120         met  05         1
# 121         met  05         1
# 122         met  05         1
# 123       unmet  05         1
# 124         met  05         1
# 125         met  05         1
# 126         met  05         1
# 127         met  05         1
# 128         met  05         1
# 129         met  05         1
# 130         met  05         2
# 131         met  05         2
# 132         met  05         2
# 133       unmet  05         2
# 134         met  05         2
# 135       unmet  05         2
# 136         met  05         2
# 137       unmet  05         2
# 138       unmet  05         2
# 139         met  05         2
# 140       unmet  05         2
# 141         met  05         2
# 142         met  05         3
# 143       unmet  05         3
# 144         met  05         3
# 145         met  05         3
# 146         met  05         3
# 147       unmet  05         3

# %% [markdown]
# ## 1.2 Normalize Requirements Status

# %%
import re
import pandas as pd

def derive_status_from_acs(row, ac_cols=None):
    # Auto-detect AC status columns like ac_1_status, ac_2_status, ...
    if ac_cols is None:
        ac_cols = [c for c in row.index if re.fullmatch(r"ac_\d+_status", c)]
    vals = []
    for c in ac_cols:
        v = row.get(c)
        if pd.notna(v):
            s = str(v).strip().lower()
            if s:
                vals.append(s)

    if not vals:
        # If no AC statuses present, keep existing status (or return None)
        return row.get("status")

    if all(v == "met" for v in vals):
        return "met"
    if all(v == "unmet" for v in vals):
        return "unmet"
    return "partially_met"

# Apply to your combined DataFrame
combined["status_norm"] = combined.apply(derive_status_from_acs, axis=1)

# Optional quick sanity check
print(combined["status_norm"].value_counts(dropna=False))
display(combined[["rand_id", "status", "status_norm", "ac_1_status", "ac_2_status", "ac_3_status"]].head(10))
# Out:
# status_norm
# met              85
# unmet            31
# partially_met    31
# error             1
# Name: count, dtype: int64
#   rand_id         status    status_norm ac_1_status ac_2_status ac_3_status
# 0    CQ26            met            met         met         met         met
# 1    DO84            met            met         met         met         met
# 2    DQ56          unmet          unmet       unmet       unmet       unmet
# 3    DQ80            met            met         met         met         met
# 4    LH51            met            met         met         met         met
# 5    MH44  partially_met  partially_met         met       unmet       unmet
# 6    MI48            met            met         met         met         met
# 7    MT45            met            met         met         met         met
# 8    SG43            met            met         met         met         met
# 9    SK83            met            met         met         met         met

# %% [markdown]
# ## 1.3 Load Goldstandard Annotations

# %%
# Load gold-standard JSONs (evaluation/goldstandard/<app_prefix>_*.json)
# into two pandas DataFrames: requirements_df and acceptance_criteria_df.

from pathlib import Path
import json
import pandas as pd

def _find_gold_root(start: Path | None = None) -> Path:
    p = (start or Path.cwd()).resolve()
    for _ in range(8):
        cand = p / "evaluation" / "goldstandard"
        if cand.exists() and cand.is_dir():
            return cand
        p = p.parent
    raise FileNotFoundError("Could not locate 'evaluation/goldstandard'")

def _norm_status(v: str | None) -> str | None:
    if v is None:
        return None
    s = str(v).strip().lower()
    aliases = {
        "met": {"met", "pass", "true", "yes", "1", "fulfilled", "satisfied"},
        "unmet": {"unmet", "not_met", "fail", "false", "no", "0", "not met", "unsatisfied", "rejected"},
        "partially_met": {"partially_met", "partially met", "partial", "mixed"},
    }
    for k, vs in aliases.items():
        if s in vs:
            return k
    if s in {"met", "unmet", "partially_met"}:
        return s
    return s  # leave as-is

def _load_json(path: Path) -> dict:
    try:
        return json.loads(path.read_text(encoding="utf-8"))
    except UnicodeDecodeError:
        return json.loads(path.read_text(encoding="latin-1", errors="replace"))

def _parse_gold_json(path: Path, app_code: str) -> tuple[pd.DataFrame, pd.DataFrame]:
    data = _load_json(path)
    app_name = str(data.get("app_name", ""))
    req_rows, ac_rows = [], []
    for req in (data.get("requirements") or []):
        rid = str(req.get("id", ""))
        desc = str(req.get("description", ""))
        rstatus = _norm_status(req.get("status"))
        rand_id = str(req.get("rand_id", ""))

        ann = req.get("annotations", {}) or {}
        ai = _norm_status(ann.get("ai"))
        ann1_ante = _norm_status(ann.get("ann1_ante"))
        ann1_post = _norm_status(ann.get("ann1_post"))
        ann2_ante = _norm_status(ann.get("ann2_ante"))
        ann2_post = _norm_status(ann.get("ann2_post"))

        req_rows.append({
            "app_code": app_code,
            "file": path.name,
            "app_name": app_name,
            "rand_id": rand_id,
            "requirement_id": rid,
            "description": desc,
            "status": rstatus,
            "ai": ai,
            "ann1_ante": ann1_ante,
            "ann1_post": ann1_post,
            "ann2_ante": ann2_ante,
            "ann2_post": ann2_post,
        })

        for ac in (req.get("acceptance_criteria") or []):
            ac_rows.append({
                "app_code": app_code,
                "file": path.name,
                "app_name": app_name,
                "rand_id": rand_id,
                "requirement_id": rid,
                "ac_id": str(ac.get("id", "")),
                "ac_text": str(ac.get("text", "")),
                "ann1_ante": _norm_status(ac.get("ann1_ante")),
                "ann1_post": _norm_status(ac.get("ann1_post")),
                "ann2_ante": _norm_status(ac.get("ann2_ante")),
                "ann2_post": _norm_status(ac.get("ann2_post")),
            })
    return pd.DataFrame(req_rows), pd.DataFrame(ac_rows)

def load_gold_into_dfs(app_prefix: str, gold_root: Path | None = None) -> tuple[pd.DataFrame, pd.DataFrame]:
    root = gold_root or _find_gold_root()
    files = sorted([p for p in (root.glob(f"{app_prefix}_*.json")) if p.is_file()])
    if not files:
        print(f"[gold] No files for prefix '{app_prefix}' in {root}")
        return pd.DataFrame(), pd.DataFrame()

    req_dfs, ac_dfs = [], []
    for f in files:
        req_df, ac_df = _parse_gold_json(f, app_code=app_prefix)
        req_dfs.append(req_df)
        ac_dfs.append(ac_df)
        print(f"[gold] Loaded {f.name}: req={len(req_df)} ac={len(ac_df)}")

    req_all = pd.concat(req_dfs, ignore_index=True) if req_dfs else pd.DataFrame()
    ac_all = pd.concat(ac_dfs, ignore_index=True) if ac_dfs else pd.DataFrame()
    return req_all, ac_all

# %%
# Example:
req_df, ac_df = load_gold_into_dfs("01")
# Out:
# [gold] Loaded 01_park-and-pay.json: req=30 ac=90

# %%
req_df
# Out:
#    app_code                  file    app_name rand_id requirement_id  \
# 0        01  01_park-and-pay.json  Park & Pay    ZX99        REQ-001
# 1        01  01_park-and-pay.json  Park & Pay    WP70        REQ-002
# 2        01  01_park-and-pay.json  Park & Pay    UP18        REQ-003
# 3        01  01_park-and-pay.json  Park & Pay    IO58        REQ-004
# 4        01  01_park-and-pay.json  Park & Pay    CQ26        REQ-005
# 5        01  01_park-and-pay.json  Park & Pay    OJ77        REQ-006
# 6        01  01_park-and-pay.json  Park & Pay    NQ89        REQ-007
# 7        01  01_park-and-pay.json  Park & Pay    ON35        REQ-008
# 8        01  01_park-and-pay.json  Park & Pay    SG43        REQ-009
# 9        01  01_park-and-pay.json  Park & Pay    PE29        REQ-010
# 10       01  01_park-and-pay.json  Park & Pay    XC11        REQ-011
# 11       01  01_park-and-pay.json  Park & Pay    RJ90        REQ-012
# 12       01  01_park-and-pay.json  Park & Pay    DO84        REQ-013
# 13       01  01_park-and-pay.json  Park & Pay    LH51        REQ-014
# 14       01  01_park-and-pay.json  Park & Pay    MI48        REQ-015
# 15       01  01_park-and-pay.json  Park & Pay    ZI45        REQ-016
# 16       01  01_park-and-pay.json  Park & Pay    SK83        REQ-017
# 17       01  01_park-and-pay.json  Park & Pay    DQ80        REQ-018
# 18       01  01_park-and-pay.json  Park & Pay    MT45        REQ-019
# 19       01  01_park-and-pay.json  Park & Pay    JT69        REQ-020
# 20       01  01_park-and-pay.json  Park & Pay    EU86        REQ-021
# 21       01  01_park-and-pay.json  Park & Pay    KB82        REQ-022
# 22       01  01_park-and-pay.json  Park & Pay    WK54        REQ-023
# 23       01  01_park-and-pay.json  Park & Pay    MH44        REQ-024
# 24       01  01_park-and-pay.json  Park & Pay    EE81        REQ-025
# 25       01  01_park-and-pay.json  Park & Pay    HG22        REQ-026
# 26       01  01_park-and-pay.json  Park & Pay    WK87        REQ-027
# 27       01  01_park-and-pay.json  Park & Pay    DQ56        REQ-028
# 28       01  01_park-and-pay.json  Park & Pay    XI89        REQ-029
# 29       01  01_park-and-pay.json  Park & Pay    NN45        REQ-030
#
#                                                                         description  \
# 0   App shall load with a combined map and list of nearby parking options source...
# 1   A toggle control shall allow users to switch between combined map-plus-list ...
# 2   Search field shall allow users to locate parking options by entering an addr...
# 3   App shall provide a price range slider to narrow parking options by hourly r...
# 4   Users shall be able to filter parking options by vehicle type such as Standa...
# 5   Each parking entry shall display its current availability status using color...
# 6   Selecting a parking entry shall open a detail panel with comprehensive spot ...
# 7   App shall allow the user to create a parking reservation stored in browser l...
# 8   User shall be able to cancel an active reservation via the reservation manag...
# 9   App shall display a live countdown timer for the upcoming reservation start ...
# 10  App shall provide step-by-step walking directions preview from current locat...
# 11              App shall simulate payment checkout to confirm reservation charges.
# 12           App shall maintain a reservation history list stored in local storage.
# 13       Users shall be able to add and remove parking spots from a favorites list.
# 14  App shall display zone-specific parking regulations within the spot detail p...
# 15  App shall present an onboarding tutorial overlay highlighting key controls o...
# 16   Parking list shall support sorting by price and by estimated walking distance.
# 17    App shall display a mock occupancy trend chart for the selected parking spot.
# 18           Users shall manage a primary vehicle profile for reservation defaults.
# 19  App shall generate a shareable deep-link that reopens the app with the reser...
# 20    App shall support scheduling reservations for any future date within 30 days.
# 21  Dragging the map shall refresh the parking list based on the map's current v...
# 22  Checkout flow shall allow entry of promo codes to apply discounts to parking...
# 23  App shall produce a downloadable parking receipt file for each completed res...
# 24  App shall automatically refresh parking availability statuses every 60 secon...
# 25  App shall verify resident parking permits by connecting to the municipal per...
# 26  App shall send browser push notifications reminding users 15 minutes before ...
# 27  App shall allow users to scan their license plate via device camera to auto-...
# 28  App shall provide an offline mode showing last-synced parking data when netw...
# 29  App shall offer a language toggle between English and Spanish across all use...
#
#            status             ai      ann1_ante      ann1_post      ann2_ante  \
# 0             met            met            met            met            met
# 1             met            met            met            met            met
# 2             met            met            met            met            met
# 3             met            met            met            met            met
# 4             met            met            met            met            met
# 5             met            met            met            met            met
# 6             met            met            met            met            met
# 7             met            met            met            met            met
# 8             met            met            met            met            met
# 9   partially_met  partially_met  partially_met  partially_met  partially_met
# 10            met            met            met            met            met
# 11            met            met            met            met            met
# 12            met            met            met            met            met
# 13            met            met            met            met            met
# 14            met            met            met            met            met
# 15            met            met            met            met            met
# 16            met            met            met            met            met
# 17            met            met            met  partially_met  partially_met
# 18            met            met  partially_met  partially_met            met
# 19  partially_met  partially_met  partially_met  partially_met  partially_met
# 20  partially_met  partially_met            met  partially_met  partially_met
# 21  partially_met  partially_met  partially_met          unmet          unmet
# 22  partially_met  partially_met  partially_met  partially_met  partially_met
# 23  partially_met  partially_met  partially_met  partially_met  partially_met
# 24          unmet          unmet          unmet          unmet          unmet
# 25          unmet          unmet          unmet          unmet          unmet
# 26          unmet          unmet          unmet          unmet          unmet
# 27          unmet          unmet          unmet          unmet          unmet
# 28          unmet          unmet          unmet          unmet  partially_met
# 29          unmet          unmet          unmet          unmet          unmet
#
#         ann2_post
# 0             met
# 1             met
# 2             met
# 3             met
# 4             met
# 5             met
# 6             met
# 7             met
# 8             met
# 9   partially_met
# 10            met
# 11            met
# 12            met
# 13            met
# 14            met
# 15            met
# 16            met
# 17  partially_met
# 18  partially_met
# 19  partially_met
# 20  partially_met
# 21          unmet
# 22  partially_met
# 23  partially_met
# 24          unmet
# 25          unmet
# 26          unmet
# 27          unmet
# 28          unmet
# 29          unmet

# %%
ac_df[:10]
# Out:
#   app_code                  file    app_name rand_id requirement_id ac_id  \
# 0       01  01_park-and-pay.json  Park & Pay    ZX99        REQ-001   AC1
# 1       01  01_park-and-pay.json  Park & Pay    ZX99        REQ-001   AC2
# 2       01  01_park-and-pay.json  Park & Pay    ZX99        REQ-001   AC3
# 3       01  01_park-and-pay.json  Park & Pay    WP70        REQ-002   AC1
# 4       01  01_park-and-pay.json  Park & Pay    WP70        REQ-002   AC2
# 5       01  01_park-and-pay.json  Park & Pay    WP70        REQ-002   AC3
# 6       01  01_park-and-pay.json  Park & Pay    UP18        REQ-003   AC1
# 7       01  01_park-and-pay.json  Park & Pay    UP18        REQ-003   AC2
# 8       01  01_park-and-pay.json  Park & Pay    UP18        REQ-003   AC3
# 9       01  01_park-and-pay.json  Park & Pay    IO58        REQ-004   AC1
#
#                                                                            ac_text  \
# 0  When the prototype loads, a default city map view is displayed with parking ...
# 1  Parking list panel is populated automatically with at least five seeded park...
# 2  No user interaction is required to see initial parking options in both map a...
# 3              Toggle button labeled 'Map/List' is visible on the primary toolbar.
# 4       Clicking the toggle hides the map and expands the list view to full width.
# 5  Clicking the toggle again restores the combined map and list layout without ...
# 6               Search field accepts free-text input of at least three characters.
# 7  Submitting a search filters the list to entries matching address or landmark...
# 8   Map re-centers to the first matching parking location after search submission.
# 9         Price slider allows selection of minimum and maximum hourly rate values.
#
#   ann1_ante ann1_post ann2_ante ann2_post
# 0       met       met       met       met
# 1       met       met       met       met
# 2       met       met       met       met
# 3       met       met       met       met
# 4       met       met       met       met
# 5       met       met       met       met
# 6       met       met       met       met
# 7       met       met       met       met
# 8       met       met       met       met
# 9       met       met       met       met

# %%
apps = ["01", "02", "03", "04", "05"]

all_req_dfs = []
all_ac_dfs = []
for app_prefix in apps:
    req_df, ac_df = load_gold_into_dfs(app_prefix)  # uses the helpers defined earlier
    all_req_dfs.append(req_df)
    all_ac_dfs.append(ac_df)

req_all = pd.concat([df for df in all_req_dfs if not df.empty], ignore_index=True) if all_req_dfs else pd.DataFrame()
ac_all  = pd.concat([df for df in all_ac_dfs if not df.empty], ignore_index=True)  if all_ac_dfs  else pd.DataFrame()

print(f"Requirements: {len(req_all)} rows across {len(apps)} apps")
print(f"ACs:          {len(ac_all)} rows across {len(apps)} apps")
display(req_all.head())
display(ac_all.head())
# Out:
# [gold] Loaded 01_park-and-pay.json: req=30 ac=90
# [gold] Loaded 02_budget-tracker.json: req=30 ac=90
# [gold] Loaded 03_recipe-generator.json: req=30 ac=90
# [gold] Loaded 04_fitness-challenges.json: req=30 ac=90
# [gold] Loaded 05_cleaning-booking.json: req=30 ac=90
# Requirements: 150 rows across 5 apps
# ACs:          450 rows across 5 apps
#   app_code                  file    app_name rand_id requirement_id  \
# 0       01  01_park-and-pay.json  Park & Pay    ZX99        REQ-001
# 1       01  01_park-and-pay.json  Park & Pay    WP70        REQ-002
# 2       01  01_park-and-pay.json  Park & Pay    UP18        REQ-003
# 3       01  01_park-and-pay.json  Park & Pay    IO58        REQ-004
# 4       01  01_park-and-pay.json  Park & Pay    CQ26        REQ-005
#
#                                                                        description  \
# 0  App shall load with a combined map and list of nearby parking options source...
# 1  A toggle control shall allow users to switch between combined map-plus-list ...
# 2  Search field shall allow users to locate parking options by entering an addr...
# 3  App shall provide a price range slider to narrow parking options by hourly r...
# 4  Users shall be able to filter parking options by vehicle type such as Standa...
#
#   status   ai ann1_ante ann1_post ann2_ante ann2_post
# 0    met  met       met       met       met       met
# 1    met  met       met       met       met       met
# 2    met  met       met       met       met       met
# 3    met  met       met       met       met       met
# 4    met  met       met       met       met       met
#   app_code                  file    app_name rand_id requirement_id ac_id  \
# 0       01  01_park-and-pay.json  Park & Pay    ZX99        REQ-001   AC1
# 1       01  01_park-and-pay.json  Park & Pay    ZX99        REQ-001   AC2
# 2       01  01_park-and-pay.json  Park & Pay    ZX99        REQ-001   AC3
# 3       01  01_park-and-pay.json  Park & Pay    WP70        REQ-002   AC1
# 4       01  01_park-and-pay.json  Park & Pay    WP70        REQ-002   AC2
#
#                                                                            ac_text  \
# 0  When the prototype loads, a default city map view is displayed with parking ...
# 1  Parking list panel is populated automatically with at least five seeded park...
# 2  No user interaction is required to see initial parking options in both map a...
# 3              Toggle button labeled 'Map/List' is visible on the primary toolbar.
# 4       Clicking the toggle hides the map and expands the list view to full width.
#
#   ann1_ante ann1_post ann2_ante ann2_post
# 0       met       met       met       met
# 1       met       met       met       met
# 2       met       met       met       met
# 3       met       met       met       met
# 4       met       met       met       met

# %% [markdown]
# # 2. Compute Requirements Status Performance

# %%
# Ensure string types for joining
combined["rand_id"] = combined["rand_id"].astype(str)
req_all["rand_id"] = req_all["rand_id"].astype(str)

# Select only what we need from gold (keep ann1_post as ground-truth)
gold_req = req_all[["rand_id", "requirement_id", "ann1_post"]].copy()

# Inner join to align only matching rand_ids
req_join = combined.merge(gold_req, on="rand_id", how="inner", suffixes=("", "_gold"))

print("combined rows:", len(combined))
print("gold req rows:", len(gold_req))
print("joined rows:", len(req_join))

# Show a small sample to inspect alignment (model status vs. gold ann1_post)
cols_to_show = [
    "rand_id", "requirement_id_gold", "status_norm", "ann1_post",
    "title", "requirement_description", "app", "batch_id"
]
cols_to_show = [c for c in cols_to_show if c in req_join.columns]
display(req_join[cols_to_show].head(20))

# Optionally, show non-joined (missing in gold or model) for debugging:
missing_in_gold = combined[~combined["rand_id"].isin(gold_req["rand_id"])]
missing_in_model = gold_req[~gold_req["rand_id"].isin(combined["rand_id"])]

print("Missing in gold by rand_id:", len(missing_in_gold))
print("Missing in model by rand_id:", len(missing_in_model))
if len(missing_in_gold):
    display(missing_in_gold[["rand_id", "title", "app", "batch_id"]].head(10))
if len(missing_in_model):
    display(missing_in_model.head(10))
# Out:
# combined rows: 148
# gold req rows: 150
# joined rows: 148
#    rand_id requirement_id_gold    status_norm      ann1_post  \
# 0     CQ26             REQ-005            met            met
# 1     DO84             REQ-013            met            met
# 2     DQ56             REQ-028          unmet          unmet
# 3     DQ80             REQ-018            met  partially_met
# 4     LH51             REQ-014            met            met
# 5     MH44             REQ-024  partially_met  partially_met
# 6     MI48             REQ-015            met            met
# 7     MT45             REQ-019            met  partially_met
# 8     SG43             REQ-009            met            met
# 9     SK83             REQ-017            met            met
# 10    UP18             REQ-003  partially_met            met
# 11    WK54             REQ-023  partially_met  partially_met
# 12    EE81             REQ-025          unmet          unmet
# 13    EU86             REQ-021            met  partially_met
# 14    HG22             REQ-026          unmet          unmet
# 15    IO58             REQ-004            met            met
# 16    NN45             REQ-030          unmet          unmet
# 17    NQ89             REQ-007            met            met
# 18    OJ77             REQ-006            met            met
# 19    ON35             REQ-008            met            met
#
#                                                                               title  \
# 0   Users shall be able to filter parking options by vehicle type such as Standa...
# 1            App shall maintain a reservation history list stored in local storage.
# 2   App shall allow users to scan their license plate via device camera to auto-...
# 3     App shall display a mock occupancy trend chart for the selected parking spot.
# 4        Users shall be able to add and remove parking spots from a favorites list.
# 5   App shall produce a downloadable parking receipt file for each completed res...
# 6   App shall display zone-specific parking regulations within the spot detail p...
# 7            Users shall manage a primary vehicle profile for reservation defaults.
# 8   User shall be able to cancel an active reservation via the reservation manag...
# 9    Parking list shall support sorting by price and by estimated walking distance.
# 10  Search field shall allow users to locate parking options by entering an addr...
# 11  Checkout flow shall allow entry of promo codes to apply discounts to parking...
# 12  App shall automatically refresh parking availability statuses every 60 secon...
# 13    App shall support scheduling reservations for any future date within 30 days.
# 14  App shall verify resident parking permits by connecting to the municipal per...
# 15  App shall provide a price range slider to narrow parking options by hourly r...
# 16  App shall offer a language toggle between English and Spanish across all use...
# 17  Selecting a parking entry shall open a detail panel with comprehensive spot ...
# 18  Each parking entry shall display its current availability status using color...
# 19  App shall allow the user to create a parking reservation stored in browser l...
#
#                                                             requirement_description  \
# 0   Users shall be able to filter parking options by vehicle type such as Standa...
# 1            App shall maintain a reservation history list stored in local storage.
# 2   App shall allow users to scan their license plate via device camera to auto-...
# 3     App shall display a mock occupancy trend chart for the selected parking spot.
# 4        Users shall be able to add and remove parking spots from a favorites list.
# 5   App shall produce a downloadable parking receipt file for each completed res...
# 6   App shall display zone-specific parking regulations within the spot detail p...
# 7            Users shall manage a primary vehicle profile for reservation defaults.
# 8   User shall be able to cancel an active reservation via the reservation manag...
# 9    Parking list shall support sorting by price and by estimated walking distance.
# 10  Search field shall allow users to locate parking options by entering an addr...
# 11  Checkout flow shall allow entry of promo codes to apply discounts to parking...
# 12  App shall automatically refresh parking availability statuses every 60 secon...
# 13    App shall support scheduling reservations for any future date within 30 days.
# 14  App shall verify resident parking permits by connecting to the municipal per...
# 15  App shall provide a price range slider to narrow parking options by hourly r...
# 16  App shall offer a language toggle between English and Spanish across all use...
# 17  Selecting a parking entry shall open a detail panel with comprehensive spot ...
# 18  Each parking entry shall display its current availability status using color...
# 19  App shall allow the user to create a parking reservation stored in browser l...
#
#    app  batch_id
# 0   01         1
# 1   01         1
# 2   01         1
# 3   01         1
# 4   01         1
# 5   01         1
# 6   01         1
# 7   01         1
# 8   01         1
# 9   01         1
# 10  01         1
# 11  01         1
# 12  01         2
# 13  01         2
# 14  01         2
# 15  01         2
# 16  01         2
# 17  01         2
# 18  01         2
# 19  01         2
# Missing in gold by rand_id: 0
# Missing in model by rand_id: 2
#     rand_id requirement_id      ann1_post
# 48     CU65        REQ-019  partially_met
# 139    KB29        REQ-020  partially_met

# %%
from sklearn.metrics import precision_recall_fscore_support
import pandas as pd

labels = ["met", "unmet", "partially_met"]

df = req_join.copy()
df = df[df["status"].notna() & df["ann1_post"].notna()]
df = df[df["status"].isin(labels) & df["ann1_post"].isin(labels)]

rows = []
for app, g in df.groupby("app", dropna=False):
    y_true = g["ann1_post"]
    y_pred = g["status"]

    p, r, f1, support = precision_recall_fscore_support(
        y_true, y_pred, labels=labels, zero_division=0
    )
    for lbl, p_i, r_i, f1_i, s_i in zip(labels, p, r, f1, support):
        rows.append({
            "app": app,
            "label": lbl,
            "precision": p_i,
            "recall": r_i,
            "f1": f1_i,
            "support": int(s_i),
        })

per_app_metrics = pd.DataFrame(rows).sort_values(["app", "label"]).reset_index(drop=True)
display(per_app_metrics)

# Optional quick pivot to see F1 per label by app
display(per_app_metrics.pivot(index="app", columns="label", values="f1").round(3))
# Out:
#    app          label  precision    recall        f1  support
# 0   01            met   0.789474  0.937500  0.857143       16
# 1   01  partially_met   0.500000  0.428571  0.461538        7
# 2   01          unmet   1.000000  0.714286  0.833333        7
# 3   02            met   1.000000  0.944444  0.971429       18
# 4   02  partially_met   0.833333  1.000000  0.909091        5
# 5   02          unmet   1.000000  1.000000  1.000000        6
# 6   03            met   0.933333  0.823529  0.875000       17
# 7   03  partially_met   0.625000  0.833333  0.714286        6
# 8   03          unmet   0.833333  0.833333  0.833333        6
# 9   04            met   1.000000  0.823529  0.903226       17
# 10  04  partially_met   0.500000  0.666667  0.571429        6
# 11  04          unmet   0.750000  0.857143  0.800000        7
# 12  05            met   0.850000  1.000000  0.918919       17
# 13  05  partially_met   0.666667  0.400000  0.500000        5
# 14  05          unmet   1.000000  0.857143  0.923077        7
# label    met  partially_met  unmet
# app
# 01     0.857          0.462  0.833
# 02     0.971          0.909  1.000
# 03     0.875          0.714  0.833
# 04     0.903          0.571  0.800
# 05     0.919          0.500  0.923

# %%
import pandas as pd

labels = ["met", "unmet", "partially_met"]

# per_app_metrics is the long-form table from earlier
wide = per_app_metrics.pivot(index="app", columns="label", values=["precision", "recall", "f1"])

# Ensure all labels exist as columns (fill missing with 0.0)
wide = wide.reindex(columns=pd.MultiIndex.from_product([["precision", "recall", "f1"], labels]), fill_value=0.0)

# Reorder columns: met (P,R,F1) → unmet (P,R,F1) → partially_met (P,R,F1)
ordered_cols = []
for lbl in labels:
    ordered_cols += [("precision", lbl), ("recall", lbl), ("f1", lbl)]
wide = wide[ordered_cols]

# Flatten column names to e.g., met_P, met_R, met_F1, unmet_P, ...
name_map = {"precision": "P", "recall": "R", "f1": "F1"}
wide.columns = [f"{lbl}_{name_map[m]}" for m, lbl in wide.columns]

wide = wide.reset_index()
display(wide.round(3))
# Out:
#   app  met_P  met_R  met_F1  unmet_P  unmet_R  unmet_F1  partially_met_P  \
# 0  01  0.789  0.938   0.857    1.000    0.714     0.833            0.500
# 1  02  1.000  0.944   0.971    1.000    1.000     1.000            0.833
# 2  03  0.933  0.824   0.875    0.833    0.833     0.833            0.625
# 3  04  1.000  0.824   0.903    0.750    0.857     0.800            0.500
# 4  05  0.850  1.000   0.919    1.000    0.857     0.923            0.667
#
#    partially_met_R  partially_met_F1
# 0            0.429             0.462
# 1            1.000             0.909
# 2            0.833             0.714
# 3            0.667             0.571
# 4            0.400             0.500

# %% [markdown]
# # 3. Compute Acceptance Criteria Performance

# %%
ac_all[:10]
# Out:
#   app_code                  file    app_name rand_id requirement_id ac_id  \
# 0       01  01_park-and-pay.json  Park & Pay    ZX99        REQ-001   AC1
# 1       01  01_park-and-pay.json  Park & Pay    ZX99        REQ-001   AC2
# 2       01  01_park-and-pay.json  Park & Pay    ZX99        REQ-001   AC3
# 3       01  01_park-and-pay.json  Park & Pay    WP70        REQ-002   AC1
# 4       01  01_park-and-pay.json  Park & Pay    WP70        REQ-002   AC2
# 5       01  01_park-and-pay.json  Park & Pay    WP70        REQ-002   AC3
# 6       01  01_park-and-pay.json  Park & Pay    UP18        REQ-003   AC1
# 7       01  01_park-and-pay.json  Park & Pay    UP18        REQ-003   AC2
# 8       01  01_park-and-pay.json  Park & Pay    UP18        REQ-003   AC3
# 9       01  01_park-and-pay.json  Park & Pay    IO58        REQ-004   AC1
#
#                                                                            ac_text  \
# 0  When the prototype loads, a default city map view is displayed with parking ...
# 1  Parking list panel is populated automatically with at least five seeded park...
# 2  No user interaction is required to see initial parking options in both map a...
# 3              Toggle button labeled 'Map/List' is visible on the primary toolbar.
# 4       Clicking the toggle hides the map and expands the list view to full width.
# 5  Clicking the toggle again restores the combined map and list layout without ...
# 6               Search field accepts free-text input of at least three characters.
# 7  Submitting a search filters the list to entries matching address or landmark...
# 8   Map re-centers to the first matching parking location after search submission.
# 9         Price slider allows selection of minimum and maximum hourly rate values.
#
#   ann1_ante ann1_post ann2_ante ann2_post
# 0       met       met       met       met
# 1       met       met       met       met
# 2       met       met       met       met
# 3       met       met       met       met
# 4       met       met       met       met
# 5       met       met       met       met
# 6       met       met       met       met
# 7       met       met       met       met
# 8       met       met       met       met
# 9       met       met       met       met

# %%
import pandas as pd

def to_ac_long(df: pd.DataFrame) -> pd.DataFrame:
    rows = []
    for _, r in df.iterrows():
        for i in (1, 2, 3):
            status = r.get(f"ac_{i}_status")
            text = r.get(f"ac_{i}_text")
            if pd.isna(status) or str(status).strip() == "":
                continue
            rows.append({
                "app": str(r.get("app", "")),
                "rand_id": str(r.get("rand_id", "")),
                "requirement_id": r.get("requirement_id", ""),
                "ac_id": f"AC{i}",
                "ac_text_model": text,
                "ac_status_model": str(status).strip().lower(),  # met/unmet
            })
    return pd.DataFrame(rows)

model_ac_long = to_ac_long(combined)
display(model_ac_long.head(10))
print("Rows:", len(model_ac_long))
# Out:
#   app rand_id                        requirement_id ac_id  \
# 0  01    CQ26  2aa7e914-3995-4185-a6e0-87b60d01584f   AC1
# 1  01    CQ26  2aa7e914-3995-4185-a6e0-87b60d01584f   AC2
# 2  01    CQ26  2aa7e914-3995-4185-a6e0-87b60d01584f   AC3
# 3  01    DO84  de7e84a1-a821-43b6-a476-349d4a2907da   AC1
# 4  01    DO84  de7e84a1-a821-43b6-a476-349d4a2907da   AC2
# 5  01    DO84  de7e84a1-a821-43b6-a476-349d4a2907da   AC3
# 6  01    DQ56  f026cdd0-a01b-4dab-b13f-50847d7216be   AC1
# 7  01    DQ56  f026cdd0-a01b-4dab-b13f-50847d7216be   AC2
# 8  01    DQ56  f026cdd0-a01b-4dab-b13f-50847d7216be   AC3
# 9  01    DQ80  e708410e-711c-4183-ae46-bce1889baff9   AC1
#
#                                                                      ac_text_model  \
# 0           Vehicle type filter displays options for Standard, EV, and Motorcycle.
# 1         Selecting a vehicle type updates the list to show only compatible spots.
# 2  Filter selection persists while the user navigates between map and detail vi...
# 3                 Previous reservations persist across sessions via local storage.
# 4                   History view lists spot name, date, duration, and amount paid.
# 5  User can clear history via dedicated control which wipes the local storage e...
# 6       Vehicle profile view offers a 'Scan Plate' option using the device camera.
# 7                       Captured image is processed to recognize plate characters.
# 8  Recognized plate auto-populates corresponding input fields with an option to...
# 9     Detail view includes a mini chart element with hourly occupancy percentages.
#
#   ac_status_model
# 0             met
# 1             met
# 2             met
# 3             met
# 4             met
# 5             met
# 6           unmet
# 7           unmet
# 8           unmet
# 9             met
# Rows: 441

# %%
gold_ac = ac_all.copy()

# Ensure string types for join keys
model_ac_long["rand_id"] = model_ac_long["rand_id"].astype(str)
model_ac_long["ac_id"]   = model_ac_long["ac_id"].astype(str)
gold_ac["rand_id"]       = gold_ac["rand_id"].astype(str)
gold_ac["ac_id"]         = gold_ac["ac_id"].astype(str)

ac_join = model_ac_long.merge(
    gold_ac[["rand_id", "ac_id", "ac_text", "ann1_post"]],
    on=["rand_id", "ac_id"],
    how="inner",
    suffixes=("_model", "_gold")
)

print("model AC rows:", len(model_ac_long))
print("gold AC rows:", len(gold_ac))
print("joined AC rows:", len(ac_join))

display(ac_join.head(20))
# Out:
# model AC rows: 441
# gold AC rows: 450
# joined AC rows: 441
#    app rand_id                        requirement_id ac_id  \
# 0   01    CQ26  2aa7e914-3995-4185-a6e0-87b60d01584f   AC1
# 1   01    CQ26  2aa7e914-3995-4185-a6e0-87b60d01584f   AC2
# 2   01    CQ26  2aa7e914-3995-4185-a6e0-87b60d01584f   AC3
# 3   01    DO84  de7e84a1-a821-43b6-a476-349d4a2907da   AC1
# 4   01    DO84  de7e84a1-a821-43b6-a476-349d4a2907da   AC2
# 5   01    DO84  de7e84a1-a821-43b6-a476-349d4a2907da   AC3
# 6   01    DQ56  f026cdd0-a01b-4dab-b13f-50847d7216be   AC1
# 7   01    DQ56  f026cdd0-a01b-4dab-b13f-50847d7216be   AC2
# 8   01    DQ56  f026cdd0-a01b-4dab-b13f-50847d7216be   AC3
# 9   01    DQ80  e708410e-711c-4183-ae46-bce1889baff9   AC1
# 10  01    DQ80  e708410e-711c-4183-ae46-bce1889baff9   AC2
# 11  01    DQ80  e708410e-711c-4183-ae46-bce1889baff9   AC3
# 12  01    LH51  ffd0117f-5cea-4bd7-90d5-160f4d2b8e46   AC1
# 13  01    LH51  ffd0117f-5cea-4bd7-90d5-160f4d2b8e46   AC2
# 14  01    LH51  ffd0117f-5cea-4bd7-90d5-160f4d2b8e46   AC3
# 15  01    MH44  6e04c7f6-523a-47e8-b3e4-d0d2019fcbf5   AC1
# 16  01    MH44  6e04c7f6-523a-47e8-b3e4-d0d2019fcbf5   AC2
# 17  01    MH44  6e04c7f6-523a-47e8-b3e4-d0d2019fcbf5   AC3
# 18  01    MI48  4dc4be42-614b-494f-b2d2-71d2b01dfc3e   AC1
# 19  01    MI48  4dc4be42-614b-494f-b2d2-71d2b01dfc3e   AC2
#
#                                                                       ac_text_model  \
# 0            Vehicle type filter displays options for Standard, EV, and Motorcycle.
# 1          Selecting a vehicle type updates the list to show only compatible spots.
# 2   Filter selection persists while the user navigates between map and detail vi...
# 3                  Previous reservations persist across sessions via local storage.
# 4                    History view lists spot name, date, duration, and amount paid.
# 5   User can clear history via dedicated control which wipes the local storage e...
# 6        Vehicle profile view offers a 'Scan Plate' option using the device camera.
# 7                        Captured image is processed to recognize plate characters.
# 8   Recognized plate auto-populates corresponding input fields with an option to...
# 9      Detail view includes a mini chart element with hourly occupancy percentages.
# 10                       Chart updates to reflect data for the newly selected spot.
# 11                  Chart includes a legend showing the meaning of axes and colors.
# 12                            Each parking card includes a favorite toggle control.
# 13                      Selected favorites appear in a dedicated favorites section.
# 14  Removing a favorite updates both the favorites list and the original card in...
# 15            After payment confirmation, user can tap a 'Download Receipt' action.
# 16  Action generates a PDF or equivalent document with reservation and payment d...
# 17    Receipt file saves to the user's device via standard browser download prompt.
# 18  Detail panel includes a regulation summary specific to the selected parking ...
# 19  Regulation summary covers maximum duration, permit requirements, and enforce...
#
#    ac_status_model  \
# 0              met
# 1              met
# 2              met
# 3              met
# 4              met
# 5              met
# 6            unmet
# 7            unmet
# 8            unmet
# 9              met
# 10             met
# 11             met
# 12             met
# 13             met
# 14             met
# 15             met
# 16           unmet
# 17           unmet
# 18             met
# 19             met
#
#                                                                             ac_text  \
# 0            Vehicle type filter displays options for Standard, EV, and Motorcycle.
# 1          Selecting a vehicle type updates the list to show only compatible spots.
# 2   Filter selection persists while the user navigates between map and detail vi...
# 3                  Previous reservations persist across sessions via local storage.
# 4                    History view lists spot name, date, duration, and amount paid.
# 5   User can clear history via dedicated control which wipes the local storage e...
# 6        Vehicle profile view offers a 'Scan Plate' option using the device camera.
# 7                        Captured image is processed to recognize plate characters.
# 8   Recognized plate auto-populates corresponding input fields with an option to...
# 9      Detail view includes a mini chart element with hourly occupancy percentages.
# 10                       Chart updates to reflect data for the newly selected spot.
# 11                  Chart includes a legend showing the meaning of axes and colors.
# 12                            Each parking card includes a favorite toggle control.
# 13                      Selected favorites appear in a dedicated favorites section.
# 14  Removing a favorite updates both the favorites list and the original card in...
# 15            After payment confirmation, user can tap a 'Download Receipt' action.
# 16  Action generates a PDF or equivalent document with reservation and payment d...
# 17    Receipt file saves to the user's device via standard browser download prompt.
# 18  Detail panel includes a regulation summary specific to the selected parking ...
# 19  Regulation summary covers maximum duration, permit requirements, and enforce...
#
#    ann1_post
# 0        met
# 1        met
# 2        met
# 3        met
# 4        met
# 5        met
# 6      unmet
# 7      unmet
# 8      unmet
# 9        met
# 10       met
# 11     unmet
# 12       met
# 13       met
# 14       met
# 15       met
# 16     unmet
# 17     unmet
# 18       met
# 19       met

# %%
from sklearn.metrics import precision_recall_fscore_support
import pandas as pd

valid = {"met", "unmet"}
ac_eval = ac_join.copy()
ac_eval = ac_eval[
    ac_eval["ac_status_model"].isin(valid) & ac_eval["ann1_post"].isin(valid)
].copy()

def prf_binary(y_true, y_pred, positive: str):
    y_true_pos = (y_true == positive)
    y_pred_pos = (y_pred == positive)
    p, r, f1, _ = precision_recall_fscore_support(
        y_true_pos, y_pred_pos, average="binary", zero_division=0
    )
    return p, r, f1

rows = []
for app, g in ac_eval.groupby("app", dropna=False):
    p_m, r_m, f1_m = prf_binary(g["ann1_post"], g["ac_status_model"], "met")
    p_u, r_u, f1_u = prf_binary(g["ann1_post"], g["ac_status_model"], "unmet")
    rows.append({
        "app": app,
        "met_P": p_m, "met_R": r_m, "met_F1": f1_m,
        "unmet_P": p_u, "unmet_R": r_u, "unmet_F1": f1_u,
    })

ac_metrics_by_app = pd.DataFrame(rows).sort_values("app").reset_index(drop=True)
display(ac_metrics_by_app.round(3))
# Out:
#   app  met_P  met_R  met_F1  unmet_P  unmet_R  unmet_F1
# 0  01  0.908  0.967   0.937    0.920    0.793     0.852
# 1  02  0.968  0.984   0.976    0.958    0.920     0.939
# 2  03  0.931  0.900   0.915    0.793    0.852     0.821
# 3  04  0.946  0.898   0.922    0.824    0.903     0.862
# 4  05  0.909  1.000   0.952    1.000    0.778     0.875

# %% [markdown]
# # 4. Compute Efficiency Statistics

# %%
import pandas as pd

metrics = {
    "#Steps": "steps_taken",
    "Time (s)": "elapsed_s",
    "#In-Tok.": "usage_input_tokens",
    "#Out-Tok.": "usage_output_tokens",
}

df_eff = combined.copy()

# Ensure numeric dtypes
for col in metrics.values():
    if col in df_eff.columns:
        df_eff[col] = pd.to_numeric(df_eff[col], errors="coerce")

# Group by app and compute mean/sd
rows = []
for app, g in df_eff.groupby("app", dropna=False):
    row = {"app": app}
    for label, col in metrics.items():
        row[f"{label} Av."] = g[col].mean()
        row[f"{label} SD"]  = g[col].std(ddof=1)
    rows.append(row)

eff_stats = pd.DataFrame(rows).sort_values("app").reset_index(drop=True)

# Optional formatting and SD NaN -> 0.0 if single sample
sd_cols = [c for c in eff_stats.columns if c.endswith("SD")]
eff_stats[sd_cols] = eff_stats[sd_cols].fillna(0.0)

display(eff_stats.round({
    "#Steps Av.": 1, "#Steps SD": 1,
    "Time (s) Av.": 2, "Time (s) SD": 2,
    "#In-Tok. Av.": 0, "#In-Tok. SD": 0,
    "#Out-Tok. Av.": 0, "#Out-Tok. SD": 0,
}))
# Out:
#   app  #Steps Av.  #Steps SD  Time (s) Av.  Time (s) SD  #In-Tok. Av.  \
# 0  01        25.1       17.4        335.98       291.23      229776.0
# 1  02        21.1       14.9        322.33       316.01      189710.0
# 2  03        19.5       16.6        223.14       240.53      174555.0
# 3  04        22.3       12.4        293.44       182.27      202726.0
# 4  05        34.2       19.8        412.87       266.67      311923.0
#
#    #In-Tok. SD  #Out-Tok. Av.  #Out-Tok. SD
# 0     165507.0         2394.0        1323.0
# 1     127758.0         1984.0         817.0
# 2     149196.0         2002.0        1020.0
# 3     107710.0         2115.0         822.0
# 4     187972.0         2850.0        1399.0

# %%
COST_IN_PER_MTOK = 3.0
COST_OUT_PER_MTOK = 12.0

eff_stats["Cost In ($)"]  = (eff_stats["#In-Tok. Av."]  / 1_000_000.0) * COST_IN_PER_MTOK
eff_stats["Cost Out ($)"] = (eff_stats["#Out-Tok. Av."] / 1_000_000.0) * COST_OUT_PER_MTOK

display(eff_stats.round({
    "#Steps Av.": 1, "#Steps SD": 1,
    "Time (s) Av.": 2, "Time (s) SD": 2,
    "#In-Tok. Av.": 0, "#In-Tok. SD": 0,
    "#Out-Tok. Av.": 0, "#Out-Tok. SD": 0,
    "Cost In ($)": 4, "Cost Out ($)": 4,
}))
# Out:
#   app  #Steps Av.  #Steps SD  Time (s) Av.  Time (s) SD  #In-Tok. Av.  \
# 0  01        25.1       17.4        335.98       291.23      229776.0
# 1  02        21.1       14.9        322.33       316.01      189710.0
# 2  03        19.5       16.6        223.14       240.53      174555.0
# 3  04        22.3       12.4        293.44       182.27      202726.0
# 4  05        34.2       19.8        412.87       266.67      311923.0
#
#    #In-Tok. SD  #Out-Tok. Av.  #Out-Tok. SD  Cost In ($)  Cost Out ($)
# 0     165507.0         2394.0        1323.0       0.6893        0.0287
# 1     127758.0         1984.0         817.0       0.5691        0.0238
# 2     149196.0         2002.0        1020.0       0.5237        0.0240
# 3     107710.0         2115.0         822.0       0.6082        0.0254
# 4     187972.0         2850.0        1399.0       0.9358        0.0342

# %% [markdown]
# # 5. Combined Results Table

# %%
req_df = wide.copy()
req_df.columns = [c if c == "app" else f"{c} (Req)" for c in req_df.columns]

ac_df = ac_metrics_by_app.copy()
ac_df.columns = [c if c == "app" else f"{c} (AC)" for c in ac_df.columns]

final = (
    req_df.merge(ac_df, on="app", how="inner")
          .merge(eff_stats, on="app", how="inner")
)

print("Rows:", len(final), "Cols:", len(final.columns))
display(final.round(3))
# Out:
# Rows: 5 Cols: 26
#   app  met_P (Req)  met_R (Req)  met_F1 (Req)  unmet_P (Req)  unmet_R (Req)  \
# 0  01        0.789        0.938         0.857          1.000          0.714
# 1  02        1.000        0.944         0.971          1.000          1.000
# 2  03        0.933        0.824         0.875          0.833          0.833
# 3  04        1.000        0.824         0.903          0.750          0.857
# 4  05        0.850        1.000         0.919          1.000          0.857
#
#    unmet_F1 (Req)  partially_met_P (Req)  partially_met_R (Req)  \
# 0           0.833                  0.500                  0.429
# 1           1.000                  0.833                  1.000
# 2           0.833                  0.625                  0.833
# 3           0.800                  0.500                  0.667
# 4           0.923                  0.667                  0.400
#
#    partially_met_F1 (Req)  met_P (AC)  met_R (AC)  met_F1 (AC)  unmet_P (AC)  \
# 0                   0.462       0.908       0.967        0.937         0.920
# 1                   0.909       0.968       0.984        0.976         0.958
# 2                   0.714       0.931       0.900        0.915         0.793
# 3                   0.571       0.946       0.898        0.922         0.824
# 4                   0.500       0.909       1.000        0.952         1.000
#
#    unmet_R (AC)  unmet_F1 (AC)  #Steps Av.  #Steps SD  Time (s) Av.  \
# 0         0.793          0.852      25.067     17.390       335.984
# 1         0.920          0.939      21.138     14.901       322.326
# 2         0.852          0.821      19.533     16.602       223.141
# 3         0.903          0.862      22.267     12.396       293.441
# 4         0.778          0.875      34.172     19.837       412.873
#
#    Time (s) SD  #In-Tok. Av.  #In-Tok. SD  #Out-Tok. Av.  #Out-Tok. SD  \
# 0      291.226    229776.233   165507.008       2393.600      1322.629
# 1      316.009    189710.345   127758.364       1984.310       816.810
# 2      240.531    174555.067   149196.392       2002.433      1019.978
# 3      182.266    202726.333   107709.927       2114.733       822.488
# 4      266.665    311922.517   187972.306       2849.724      1398.934
#
#    Cost In ($)  Cost Out ($)
# 0        0.689         0.029
# 1        0.569         0.024
# 2        0.524         0.024
# 3        0.608         0.025
# 4        0.936         0.034

# %%
import pandas as pd

num_cols = final.select_dtypes(include="number").columns

avg_series = pd.Series(index=final.columns, dtype="object")
avg_series["app"] = "Average"
for c in num_cols:
    avg_series[c] = final[c].mean()

sd_series = pd.Series(index=final.columns, dtype="object")
sd_series["app"] = "SD"
for c in num_cols:
    sd_series[c] = final[c].std(ddof=1)  # sample SD; change to ddof=0 for population SD

final_with_summary = pd.concat([final, pd.DataFrame([avg_series]), pd.DataFrame([sd_series])], ignore_index=True)

display(final_with_summary.round(3))
# Out:
#        app  met_P (Req)  met_R (Req)  met_F1 (Req)  unmet_P (Req)  \
# 0       01        0.789        0.938         0.857          1.000
# 1       02        1.000        0.944         0.971          1.000
# 2       03        0.933        0.824         0.875          0.833
# 3       04        1.000        0.824         0.903          0.750
# 4       05        0.850        1.000         0.919          1.000
# 5  Average        0.915        0.906         0.905          0.917
# 6       SD        0.093        0.079         0.044          0.118
#
#    unmet_R (Req)  unmet_F1 (Req)  partially_met_P (Req)  \
# 0          0.714           0.833                  0.500
# 1          1.000           1.000                  0.833
# 2          0.833           0.833                  0.625
# 3          0.857           0.800                  0.500
# 4          0.857           0.923                  0.667
# 5          0.852           0.878                  0.625
# 6          0.102           0.082                  0.138
#
#    partially_met_R (Req)  partially_met_F1 (Req)  met_P (AC)  met_R (AC)  \
# 0                  0.429                   0.462       0.908       0.967
# 1                  1.000                   0.909       0.968       0.984
# 2                  0.833                   0.714       0.931       0.900
# 3                  0.667                   0.571       0.946       0.898
# 4                  0.400                   0.500       0.909       1.000
# 5                  0.666                   0.631       0.933       0.950
# 6                  0.258                   0.183       0.026       0.048
#
#    met_F1 (AC)  unmet_P (AC)  unmet_R (AC)  unmet_F1 (AC)  #Steps Av.  \
# 0        0.937         0.920         0.793          0.852      25.067
# 1        0.976         0.958         0.920          0.939      21.138
# 2        0.915         0.793         0.852          0.821      19.533
# 3        0.922         0.824         0.903          0.862      22.267
# 4        0.952         1.000         0.778          0.875      34.172
# 5        0.940         0.899         0.849          0.870      24.435
# 6        0.025         0.088         0.064          0.043       5.805
#
#    #Steps SD  Time (s) Av.  Time (s) SD  #In-Tok. Av.  #In-Tok. SD  \
# 0     17.390       335.984      291.226    229776.233   165507.008
# 1     14.901       322.326      316.009    189710.345   127758.364
# 2     16.602       223.141      240.531    174555.067   149196.392
# 3     12.396       293.441      182.266    202726.333   107709.927
# 4     19.837       412.873      266.665    311922.517   187972.306
# 5     16.225       317.553      259.339    221738.099   147628.799
# 6      2.782        68.817       51.420     54339.911    31376.890
#
#    #Out-Tok. Av.  #Out-Tok. SD  Cost In ($)  Cost Out ($)
# 0       2393.600      1322.629        0.689         0.029
# 1       1984.310       816.810        0.569         0.024
# 2       2002.433      1019.978        0.524         0.024
# 3       2114.733       822.488        0.608         0.025
# 4       2849.724      1398.934        0.936         0.034
# 5       2268.960      1076.168        0.665         0.027
# 6        363.548       273.724        0.163         0.004
